# %%
import pandas as pd

from bs4 import BeautifulSoup as soup

import requests as req

url = "https://www.youtube.com/feed/trending"

page = req.get(url)


con = page.content

man = soup(con,'html.parser')

for x in man.findAll("div",{"id" : "content"}):
    g = x.findAll("a",{"class":"yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink spf-link"})
    for i in g:
        print(i.text)
# Out:
# YADAVUNNADHO FULL VIDEO SONG | LATEST FOLK SONG 2020 | TIK-TOK STARS AKHIL, RAVALI | SIRIMUVVA MUSIC
# Pregnant elephant dies allegedly after eating pineapple filled with crackers
# HUSTLE BUSTLE | The Story of Dynamo Gaming
# Quarantine With Valentine - Part 3 | Sheetal Gauthaman | Pruthvi Mukka | Infinitum Media
# Meri Aashiqui Song | Rochak Kohli Feat. Jubin Nautiyal | Ihana Dhillon,Altamash Faraz| Bhushan Kumar
# అల్లరి పిల్లలు | My Village Show Comedy | Gangavva | part-1
# Oneplus 8 Unboxing & initial impressions ll in Telugu ll
# THE DAJJAL'S SCARY I PET GOAT 2 EXPLAINED ! (part 2) (Hindi Urdu) | TBV Knowledge & Truth
# Kerala Elephant Incident | MP Maneka Gandhi & Bollywood Celebrities Demands Strict Action
# 4 Minutes 24 Headlines - TV9
# REWIND 2020 with NAVEEN POLISHETTY | JAATHI RATNALU | NEW TELUGU MOVIE |  COMEDY
# Ranga Nayaka Sagar Pote || My Village Comedy || Dheeraj Lp || Ranganayaka Sagar Project
# ...

# %%
url = "https://www.youtube.com/"

q = req.get(url)

s = q.content

d = soup(s,'html.parser')

for x in d.findAll("div",{"id":"content"}):
    g = x.findAll("div",{"class":"yt-lockup-content"})
    for p in g:
        o = p.findAll("a")
        for j in o:
            print(j.text)
# Out:
# Are ye to asli hai 😳 | Playing With Randoms | PUBG MOBILE
# SOUL Regaltos
# FilterCopy | Types Of Men You Meet On A Date | Ft. Irrfan and Parvathy
# FilterCopy
# Home Tour- Gaurav Kapur and Kirat Bhattal’s elegant and calm Mumbai home
# Beautiful Homes
# The PERFECT 10 Minute Daily Posture Routine (FIX YOUR SIT!)
# Jeremy Ethier
# Dharala Prabhu - Title Track Video | Harish Kalyan | Anirudh Ravichander | Tanya Hope
# Sony Music South
# We Made Hyderabadi Chicken Dum Biryani !!!!
# Korbin Miles
# GETTING FAMOUS WITH BB KI VINES
# CarryMinati
# BJP's Spokesperson goes Ghajini ( Memory Loss )
# Rebel Shraddha Nand Pati
# Rashmika & Vijay's Yenti Yenti Live Ramp Walk!! Wow! What an on-screen Pair! Super Cute!
# BehindwoodsTV
# How was Vlogging started ?
# Flying Beast
# Brazil 4-1 Japan 2006 Classic Match All goals & Highlights FHD/1080P
# NIXBLACK
# KBB | India's Biggest Digital Celebrity Brands  EP 02 | Carry Minati & Anisha Dixit
# CNBC-TV18
# ...

# %%
import tkinter as tk

from tkinter import font

root = tk.Tk()
width = 1200
height = 1000

canvas = tk.Canvas(root,height = height,bg = 'skyblue',width = width)
canvas.pack()



root.mainloop()

# %%
import pyautogui as py

# %%
import pandas as pd

from bs4 import BeautifulSoup as soup

import requests as req

url = "https://www.webopedia.com/quick_ref/textmessageabbreviations.asp"

page = req.get(url)

x = soup(page.content,"html.parser")

a = x.findAll("div",{"id":"article_content"})

b = a[0].findAll("td")

for x in b:
    print(x.text)
# Out:
#   Text Messaging & Chat Abbreviations: Numbers & Characters
#
#
# ?
#
#
# I have a question
#
#
# ?
#
#
# I don't understand what you mean
#
#
# ?4U
#
#
# I have a question for you
#
#
# ;S
#
#
# Gentle warning, like "Hmm? What did you say?"
#
#
# ^^
#
#
# Meaning "read line" or "read message" above
#
#
# <3
#
#
# Meaning "sideways heart" (love, friendship)
#
# <3
#
# Meaning "broken heart"
#
#
# <33
#
#
# Meaning "heart or love" (more 3s is a bigger heart)
#
#
# @TEOTD
#
#
# At the end of the day
#
#
# .02
#
#
# My (or your) two cents worth
#
#
# 1TG, 2TG
#
#
# Meaning number of items needed for win (online gaming)
#
#
# 1UP
#
#
# Meaning extra life (online gaming)
#
#
# 121
#
#
# One-to-one (private chat initiation)
#
#
# 1337
#
#
# Leet, meaning 'elite'
#
#
# 143
#
#
# I love you
#
#
# 1432
#
#
# I love you too
#
#
# 14AA41
#
#
# One for all, and all for one
#
#
# 182
#
#
# I hate you
#
#
# 19
#
#
# Zero hand (online gaming)
#
#
# 10M
#
#
# Ten man (online gaming)
#
#
# 10X
#
#
# ...

# %%
"We're supposed 2b frnds forever"
# Out:
# "We're supposed 2b frnds forever"

# %%
def wiki():
    sup = input("What you wanna know??\n")
    while sup != 'end':
        sup = input("What you wanna know??\n")
        url = "https://en.wikipedia.org/wiki/" + str(sup)

        maany = req.get(url)

        dany = soup(maany.content,"html.parser")

        a = dany.findAll("div",{"id":"bodyContent"})

        for x in a[0].findAll("td"):
            print(x.text)
            print("\n$$$$$$$$$$")

# %%
wiki()
# Out:
# What you wanna know??
#
# What you wanna know??
# joey tribbiani
# Look for Joey tribbiani on one of Wikipedia's sister projects:
#
#
#
# Wiktionary (dictionary)
#
#
#
# Wikibooks (textbooks)
#
#
#
# Wikiquote (quotations)
#
#
#
# Wikisource (library)
#
#
#
# Wikiversity (learning resources)
#
#
#
# Commons (media)
#
#
#
# Wikivoyage (travel guide)
#
#
#
# Wikinews (news source)
#
#
#
# Wikidata (linked database)
#
# Wikipedia does not have an article with this exact name. Please search for Joey tribbiani in Wikipedia to check for alternative titles or spellings.
# Log in or create an account to start the Joey tribbiani article, alternatively use the Article Wizard, or add a request for it.
# Search for "Joey tribbiani" in existing articles.
# Look for pages within Wikipedia that link to this title.
#
#
# Other reasons this message may be displayed:
#
# ...

# %%
import pandas as pd

# %%
import pandas as pd

import numpy as np
